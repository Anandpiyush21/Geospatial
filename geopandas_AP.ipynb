# %%
# !pip install geopandas
# Out:
# ...
#      ------------------------------------ 323.6/323.6 kB 742.5 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.4/1.4 MB 3.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 6.1/6.1 MB 1.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 15.9/15.9 MB 1.7 MB/s eta 0:00:00
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

pathh = gpd.read_file(r"C:\Users\anand\Code_basics\GDA\Administrative Boundary Database  AP -1\ANDHRA_PRADESH_DISTRICT_BDY.shp")
print(pathh)
# Out:
# c:\Users\anand\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\anand\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#                    District           STATE REMARKS  State_LGD DISTRICT_L  \
# 0                 ANANTAPUR  ANDHRA PRADESH    None         28        502
# 1                  CHITTOOR  ANDHRA PRADESH    None         28        503
# 2              Y S R KADAPA  ANDHRA PRADESH    None         28        504
# 3             EAST GODAVARI  ANDHRA PRADESH    None         28        505
# 4                    GUNTUR  ANDHRA PRADESH    None         28        506
# ...

# %%
print(type(pathh))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
pathh.plot()
# Out:
# <AxesSubplot:>

# %%
pathh.plot(cmap = 'jet')
# Out:
# <AxesSubplot:>

# %%
pathh.head()
# Out:
#         District           STATE REMARKS  State_LGD DISTRICT_L    Shape_Leng  \
# 0      ANANTAPUR  ANDHRA PRADESH    None         28        502  1.524560e+06
# 1       CHITTOOR  ANDHRA PRADESH    None         28        503  1.287744e+06
# 2   Y S R KADAPA  ANDHRA PRADESH    None         28        504  7.961446e+05
# 3  EAST GODAVARI  ANDHRA PRADESH    None         28        505  1.004318e+06
# 4         GUNTUR  ANDHRA PRADESH    None         28        506  8.006491e+05
#
#      Shape_Area                                           geometry
# 0  1.916556e+10  POLYGON ((3801071.388 3014724.662, 3801099.919...
# 1  1.490755e+10  MULTIPOLYGON (((3855438.914 2899547.123, 38554...
# 2  1.515527e+10  POLYGON ((3902818.679 3024755.476, 3902681.822...
# 3  1.258982e+10  POLYGON ((4266891.402 3267881.109, 4266881.795...
# 4  1.115990e+10  POLYGON ((4088235.478 3096927.416, 4088020.941...

# %%
pathh.plot(cmap = 'jet' , column = 'District', figsize = (10,10))
# Out:
# <AxesSubplot:>

# %%
pathh2 = gpd.read_file(r"C:\Users\anand\Code_basics\GDA\Administrative Boundary Database  AP -1\ANDHRA_PRADESH_STATE_HQ.shx")
pathh2.plot(cmap = 'jet')
# Out:
# <AxesSubplot:>

# %%
fig , ax = plt.subplots(1)
pathh.plot(ax=ax, cmap = 'plasma')
pathh2.plot(ax=ax , facecolor = 'yellow')
# Out:
# <AxesSubplot:>
